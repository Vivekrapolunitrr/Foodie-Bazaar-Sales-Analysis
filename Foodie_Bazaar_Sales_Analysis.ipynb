# %% [markdown]
# ## Import the libraries

# %%
import pandas as pd

# %% [markdown]
# ## Import the Data Set

# %%
ds=pd.read_csv("/content/Foodie Bazaar Sales Data.csv")

# %% [markdown]
# ## Understanding the Data

# %% [markdown]
# 1. Size of the data

# %%
ds.shape
# Out:
# (1000, 10)

# %%
ds.sample(5)
# Out:
#      order_id        date        item_name  item_type  item_price  quantity  \
# 973       974   1/28/2023          Vadapav   Fastfood          20        13
# 232       233   7/31/2022         Panipuri   Fastfood          20         5
# 713       714  12/14/2022  Sugarcane juice  Beverages          25        14
# 427       428  12/24/2022  Sugarcane juice  Beverages          25         8
# 37         38  03-08-2023         Panipuri   Fastfood          20        12
#
#      transaction_amount transaction_type received_by time_of_sale
# 973                 260           Online         Mr.    Afternoon
# 232                 100             Cash         Mr.      Morning
# 713                 350             Cash         Mr.    Afternoon
# 427                 200           Online         Mr.    Afternoon
# 37                  240           Online        Mrs.        Night

# %% [markdown]
# 2. Overview of data

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            1000 non-null   int64
#  1   date                1000 non-null   object
#  2   item_name           1000 non-null   object
#  3   item_type           1000 non-null   object
#  4   item_price          1000 non-null   int64
#  5   quantity            1000 non-null   int64
#  6   transaction_amount  1000 non-null   int64
#  7   transaction_type    893 non-null    object
#  8   received_by         1000 non-null   object
#  9   time_of_sale        1000 non-null   object
# dtypes: int64(4), object(6)
# memory usage: 78.2+ KB

# %%
ds.describe()
# Out:
#           order_id   item_price     quantity  transaction_amount
# count  1000.000000  1000.000000  1000.000000         1000.000000
# mean    500.500000    33.315000     8.162000          275.230000
# std     288.819436    14.921744     4.413075          204.402979
# min       1.000000    20.000000     1.000000           20.000000
# 25%     250.750000    20.000000     4.000000          120.000000
# 50%     500.500000    25.000000     8.000000          240.000000
# 75%     750.250000    50.000000    12.000000          360.000000
# max    1000.000000    60.000000    15.000000          900.000000

# %% [markdown]
# 3. Checking for missing values in the data

# %%
ds.isnull().sum()
# Out:
# order_id                0
# date                    0
# item_name               0
# item_type               0
# item_price              0
# quantity                0
# transaction_amount      0
# transaction_type      107
# received_by             0
# time_of_sale            0
# dtype: int64

# %% [markdown]
# 4. Checking for duplicate values in the data

# %%
ds.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Data Pre-Processing / Data Cleaning

# %% [markdown]
# 1. Filling the Missing Values with 'None'

# %%
ds.isnull().sum()
# Out:
# order_id                0
# date                    0
# item_name               0
# item_type               0
# item_price              0
# quantity                0
# transaction_amount      0
# transaction_type      107
# received_by             0
# time_of_sale            0
# dtype: int64

# %%
ds.fillna('Others' , inplace=True)

# %%
ds.head(5)
# Out:
#    order_id       date        item_name  item_type  item_price  quantity  \
# 0         1 2022-07-03         Aalopuri   Fastfood          20        13
# 1         2 2022-08-23          Vadapav   Fastfood          20        15
# 2         3 2022-11-20          Vadapav   Fastfood          20         1
# 3         4 2023-02-03  Sugarcane juice  Beverages          25         6
# 4         5 2022-10-02  Sugarcane juice  Beverages          25         8
#
#    transaction_amount transaction_type received_by time_of_sale  date_year  \
# 0                 260           Others        Male        Night       2022
# 1                 300             Cash        Male    Afternoon       2022
# 2                  20             Cash        Male    Afternoon       2022
# 3                 150           Online        Male        Night       2023
# 4                 200           Online        Male      Evening       2022
#
#    date_month_no
# 0              7
# 1              8
# 2             11
# 3              2
# 4             10

# %%
ds.isnull().sum()
# Out:
# order_id              0
# date                  0
# item_name             0
# item_type             0
# item_price            0
# quantity              0
# transaction_amount    0
# transaction_type      0
# received_by           0
# time_of_sale          0
# dtype: int64

# %% [markdown]
# Changing ('Mrs.' , 'Mr.' ) into Female and Male in 'received_by' column.

# %%
for gen in ds['received_by']:
    if gen=='Mrs.':
        ds['received_by'].replace('Mrs.','Female',inplace=True)
    elif gen=='Mr.':
        ds['received_by'].replace('Mr.','Male',inplace=True)

# %%
ds['received_by']
# Out:
# 0        Male
# 1        Male
# 2        Male
# 3        Male
# 4        Male
#         ...
# 995    Female
# 996      Male
# 997      Male
# 998    Female
# 999    Female
# Name: received_by, Length: 1000, dtype: object

# %% [markdown]
# Convert dates with multiple formats into the datatime data type

# %%
ds['date'] = pd.to_datetime(ds['date'], format='%m-%d-%Y', errors='coerce').fillna(pd.to_datetime(ds['date'], format='%m/%d/%Y', errors='coerce'))

# %%
ds['date'].dtype
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# Extracting year and month from the date column and creating new columns

# %%
ds['date_year'] = ds['date'].dt.year
ds.sample(4)
# Out:
#      order_id       date    item_name  item_type  item_price  quantity  \
# 524       525 2022-05-04      Vadapav   Fastfood          20         3
# 676       677 2022-05-19  Cold coffee  Beverages          40         3
# 150       151 2022-07-10      Frankie   Fastfood          50        13
# 377       378 2022-04-24      Vadapav   Fastfood          20         2
#
#      transaction_amount transaction_type received_by time_of_sale  date_year
# 524                  60             Cash        Male     Midnight       2022
# 676                 120           Online      Female      Morning       2022
# 150                 650           Online      Female      Morning       2022
# 377                  40             Cash      Female     Midnight       2022

# %%
ds['date_month_no'] = ds['date'].dt.month
ds.sample(3)
# Out:
#      order_id       date item_name item_type  item_price  quantity  \
# 596       597 2022-11-30  Panipuri  Fastfood          20        10
# 921       922 2022-06-13   Frankie  Fastfood          50         5
# 898       899 2023-01-24  Aalopuri  Fastfood          20         7
#
#      transaction_amount transaction_type received_by time_of_sale  date_year  \
# 596                 200           Online        Male     Midnight       2022
# 921                 250           Online      Female      Evening       2022
# 898                 140             Cash        Male     Midnight       2023
#
#      date_month_no
# 596             11
# 921              6
# 898              1

# %% [markdown]
# Downloading the analyzed csv file

# %%
ds.to_csv('my_dataset.csv', index=False)
from google.colab import files
files.download('my_dataset.csv')
